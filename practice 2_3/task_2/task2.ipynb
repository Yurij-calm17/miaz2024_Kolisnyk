# %%
# %pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.2.3-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting numpy>=1.23.2 (from pandas)
#   Downloading numpy-2.2.1-cp311-cp311-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.8 kB ? eta -:--:--
#      ------------------------- ------------ 41.0/60.8 kB 487.6 kB/s eta 0:00:01
#      ------------------------- ------------ 41.0/60.8 kB 487.6 kB/s eta 0:00:01
#      ------------------------- ------------ 41.0/60.8 kB 487.6 kB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 202.4 kB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\yurav\appdata\roaming\python\python311\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\yurav\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.2.3-cp311-cp311-win_amd64.whl (11.6 MB)
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.6 MB 991.0 kB/s eta 0:00:12
#    ---------------------------------------- 0.1/11.6 MB 1.2 MB/s eta 0:00:10
#    ---------------------------------------- 0.1/11.6 MB 1.1 MB/s eta 0:00:11
#     --------------------------------------- 0.2/11.6 MB 958.1 kB/s eta 0:00:12
#     --------------------------------------- 0.3/11.6 MB 1.4 MB/s eta 0:00:09
#    - -------------------------------------- 0.4/11.6 MB 1.4 MB/s eta 0:00:09
#    - -------------------------------------- 0.5/11.6 MB 1.5 MB/s eta 0:00:08
#    - -------------------------------------- 0.6/11.6 MB 1.6 MB/s eta 0:00:07
#    -- ------------------------------------- 0.7/11.6 MB 1.7 MB/s eta 0:00:07
#    -- ------------------------------------- 0.8/11.6 MB 1.7 MB/s eta 0:00:07
#    --- ------------------------------------ 0.9/11.6 MB 1.7 MB/s eta 0:00:07
#    --- ------------------------------------ 1.0/11.6 MB 1.8 MB/s eta 0:00:06
#    --- ------------------------------------ 1.1/11.6 MB 1.8 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.2/11.6 MB 1.9 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.4/11.6 MB 2.0 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.4/11.6 MB 2.0 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.6/11.6 MB 2.0 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.7/11.6 MB 2.0 MB/s eta 0:00:06
#    ------ --------------------------------- 1.9/11.6 MB 2.1 MB/s eta 0:00:05
#    ------ --------------------------------- 2.0/11.6 MB 2.1 MB/s eta 0:00:05
#    ------- -------------------------------- 2.2/11.6 MB 2.2 MB/s eta 0:00:05
#    ------- -------------------------------- 2.3/11.6 MB 2.2 MB/s eta 0:00:05
#    -------- ------------------------------- 2.5/11.6 MB 2.2 MB/s eta 0:00:05
#    -------- ------------------------------- 2.6/11.6 MB 2.2 MB/s eta 0:00:05
#    --------- ------------------------------ 2.8/11.6 MB 2.3 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.9/11.6 MB 2.3 MB/s eta 0:00:04
#    ---------- ----------------------------- 3.1/11.6 MB 2.4 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.2/11.6 MB 2.4 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.3/11.6 MB 2.4 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.5/11.6 MB 2.4 MB/s eta 0:00:04
#    ------------ --------------------------- 3.5/11.6 MB 2.4 MB/s eta 0:00:04
#    ------------ --------------------------- 3.6/11.6 MB 2.3 MB/s eta 0:00:04
#    ------------ --------------------------- 3.7/11.6 MB 2.3 MB/s eta 0:00:04
#    ------------- -------------------------- 4.0/11.6 MB 2.4 MB/s eta 0:00:04
#    -------------- ------------------------- 4.1/11.6 MB 2.4 MB/s eta 0:00:04
#    -------------- ------------------------- 4.3/11.6 MB 2.4 MB/s eta 0:00:04
#    --------------- ------------------------ 4.5/11.6 MB 2.5 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.8/11.6 MB 2.5 MB/s eta 0:00:03
#    ----------------- ---------------------- 5.0/11.6 MB 2.6 MB/s eta 0:00:03
#    ------------------ --------------------- 5.3/11.6 MB 2.6 MB/s eta 0:00:03
#    ------------------- -------------------- 5.5/11.6 MB 2.7 MB/s eta 0:00:03
#    ------------------- -------------------- 5.6/11.6 MB 2.7 MB/s eta 0:00:03
#    -------------------- ------------------- 5.9/11.6 MB 2.7 MB/s eta 0:00:03
#    --------------------- ------------------ 6.1/11.6 MB 2.8 MB/s eta 0:00:02
#    --------------------- ------------------ 6.2/11.6 MB 2.8 MB/s eta 0:00:02
#    ---------------------- ----------------- 6.5/11.6 MB 2.8 MB/s eta 0:00:02
#    ---------------------- ----------------- 6.6/11.6 MB 2.8 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.8/11.6 MB 2.9 MB/s eta 0:00:02
#    ------------------------ --------------- 7.1/11.6 MB 2.9 MB/s eta 0:00:02
#    ------------------------- -------------- 7.3/11.6 MB 2.9 MB/s eta 0:00:02
#    ------------------------- -------------- 7.5/11.6 MB 2.9 MB/s eta 0:00:02
#    -------------------------- ------------- 7.7/11.6 MB 3.0 MB/s eta 0:00:02
#    --------------------------- ------------ 7.9/11.6 MB 3.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.2/11.6 MB 3.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.4/11.6 MB 3.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 8.6/11.6 MB 3.1 MB/s eta 0:00:02
#    ------------------------------ --------- 8.8/11.6 MB 3.1 MB/s eta 0:00:01
#    ------------------------------ ---------
 4.5 MB/s eta 0:00:01
#    ---------------------------------------- 508.0/508.0 kB 4.0 MB/s eta 0:00:00
# Downloading tzdata-2024.2-py2.py3-none-any.whl (346 kB)
#    ---------------------------------------- 0.0/346.6 kB ? eta -:--:--
#    ------------------------- -------------- 225.3/346.6 kB 6.9 MB/s eta 0:00:01
#    ---------------------------------------- 346.6/346.6 kB 4.3 MB/s eta 0:00:00
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-2.2.1 pandas-2.2.3 pytz-2024.2 tzdata-2024.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'c:\Users\yurav\AppData\Local\Programs\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install openpyxl
# Out:
# Collecting openpyxlNote: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/250.9 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/250.9 kB 220.2 kB/s eta 0:00:01
#    ------ -------------------------------- 41.0/250.9 kB 281.8 kB/s eta 0:00:01
#    --------- ----------------------------- 61.4/250.9 kB 328.2 kB/s eta 0:00:01
#    ------------------ ------------------- 122.9/250.9 kB 516.7 kB/s eta 0:00:01
#    ------------------ ------------------- 122.9/250.9 kB 516.7 kB/s eta 0:00:01
#    -------------------------- ----------- 174.1/250.9 kB 553.5 kB/s eta 0:00:01
#    -------------------------- ----------- 174.1/250.9 kB 553.5 kB/s eta 0:00:01
#    ------------------------------- ------ 204.8/250.9 kB 498.9 kB/s eta 0:00:01
#    ------------------------------- ------ 204.8/250.9 kB 498.9 kB/s eta 0:00:01
#    ------------------------------- ------ 204.8/250.9 kB 498.9 kB/s eta 0:00:01
#    -------------------------------------- 250.9/250.9 kB 416.4 kB/s eta 0:00:00
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5

# %%
import pandas as pd

# Створення даних
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['Kyiv', 'Lviv', 'Odessa']
}

# Створення DataFrame з даних
df = pd.DataFrame(data)

# Запис даних у файл Excel
df.to_excel('data.xlsx', index=False)

print("Файл data.xlsx успішно створено!")
# Out:
# Файл data.xlsx успішно створено!

# %%
import pandas as pd

# Дані для створення Excel-файлу
data = {
    "Ім'я": ["Вадим", "Дмитро", "Артемко", "Жук", "Лотос"],
    "Дата": ["2024-12-15", "2022-11-10", "2022-11-25", "2022-12-01", "2022-10-20"],
    "Відділ": ["Рекрутинг", "Перевірка", "HR", "Контроль", "Аудит"],
}

# Створюємо DataFrame
df = pd.DataFrame(data)

# Зберігаємо у файл data.xlsx
file_path = "data.xlsx"
df.to_excel(file_path, index=False)

file_path
'data.xlsx'
import pandas as pd
from datetime import datetime, timedelta

# Шлях до файлу Excel
input_file = "data.xlsx"  # Замініть на шлях до вашого файлу
output_file = "filtered_data.xlsx"

# Читання даних з Excel
data = pd.read_excel(input_file)

# Перевіряємо, чи є в таблиці колонка з датами
date_column = "Дата"  # Замініть на назву колонки з датами у вашому файлі
if date_column not in data.columns:
    raise ValueError(f"Колонка '{date_column}' не знайдена в даних.")

# Конвертуємо колонку з датами у формат datetime
data[date_column] = pd.to_datetime(data[date_column], errors='coerce')

# Вибираємо поточний місяць
current_date = datetime.now()
last_month_start = (current_date.replace(day=1) - timedelta(days=1)).replace(day=1)
last_month_end = last_month_start.replace(day=1) + timedelta(days=31)
last_month_end = last_month_end.replace(day=1) - timedelta(days=1)

# Фільтруємо дані за останнім місяцем
filtered_data = data[(data[date_column] >= last_month_start) & (data[date_column] <= last_month_end)]

# Збереження відфільтрованих даних у новий Excel-файл
filtered_data.to_excel(output_file, index=False)

print(f"Відфільтровані дані збережено у файл '{output_file}'.")
# Out:
# Відфільтровані дані збережено у файл 'filtered_data.xlsx'.
